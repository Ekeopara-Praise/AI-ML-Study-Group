# %% [markdown]
# ## Data Gathering and cleaning of a business customer's dataset for an Exploratory analysis
#
# STEPS INVOLVED
# 1. Perform an initial exploration
# 2. Identify data quality issues
# 3. Clean data

# %% [markdown]
# ## 1. Initial Exploration

# %% [markdown]
# ### Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The dataset that is being used was gotten from Kaggle website and it is in csv format.
#
# Let's load the data into the environment

# %%
dataset = pd.read_csv('customer_churn.csv')

# %% [markdown]
# Let's view the first five rows of the data

# %%
dataset.head()
# Out:
#               Names   Age  Total_Purchase  Account_Manager  Years  Num_Sites  \
# 0  Cameron Williams  42.0        11066.80                0   7.22        8.0
# 1     Kevin Mueller  41.0        11916.22                0   6.50       11.0
# 2       Eric Lozano  38.0        12884.75                0   6.67       12.0
# 3     Phillip White  42.0         8010.76                0   6.71       10.0
# 4    Cynthia Norton  37.0         9191.58                0   5.56        9.0
#
#           Onboard_date                                           Location  \
# 0  2013-08-30 07:00:40      10265 Elizabeth Mission Barkerburgh, AK 89518
# 1  2013-08-13 00:38:46  6157 Frank Gardens Suite 019 Carloshaven, RI 1...
# 2  2016-06-29 06:20:07             1331 Keith Court Alyssahaven, DE 90114
# 3  2014-04-22 12:43:12       13120 Daniel Mount Angelabury, WY 30645-4695
# 4  2016-01-19 15:31:15                765 Tricia Row Karenshire, MH 71730
#
#                        Company  Churn
# ...

# %% [markdown]
# Observations
# 1. There are 10 features or variables on the dataset.
# 2. Four(4) features are numerical while six(6) are categorical.
# 3. The 1's and 0's in the Churn column represent Yes and No respectively. The same thing applies to the feature, **Account_Manager**
# 4. When the feature, Churn is 1, it means the customer has churned(left) and vice versa
# 5. 1 under the feature, Account_Manager means the Customer has an Account_manager

# %% [markdown]
# Let's get a general info about the data

# %%
dataset.info
# Out:
# <bound method DataFrame.info of                 Names   Age  Total_Purchase  Account_Manager  Years  \
# 0    Cameron Williams  42.0        11066.80                0   7.22
# 1       Kevin Mueller  41.0        11916.22                0   6.50
# 2         Eric Lozano  38.0        12884.75                0   6.67
# 3       Phillip White  42.0         8010.76                0   6.71
# 4      Cynthia Norton  37.0         9191.58                0   5.56
# ..                ...   ...             ...              ...    ...
# 895       Paul Miller  42.0        12800.82                1   3.62
# 896    Natalie Hodges  52.0         9893.92                0   6.91
# 897         Ana Smith  45.0        12056.18                0   5.46
# 898    Justin Leonard  51.0         6517.93                1   5.47
# 899   Joseph Williams  39.0         9315.60                1   5.02
#
#      Num_Sites         Onboard_date  \
# 0          8.0  2013-08-30 07:00:40
# 1         11.0  2013-08-13 00:38:46
# ...

# %% [markdown]
# There are 900 samples/rows on the dataset

# %% [markdown]
# ### DATA CLEANING

# %% [markdown]
# Exploring the Dataset using profile report of pandas_profiling

# %%
from pandas_profiling import ProfileReport

# %%
# Let's generate a profile report of the loaded data
profile = ProfileReport(dataset, title='Customers Data Analysis')
#profile.to_widgets()

# %%
profile.to_notebook_iframe
# Out:
# <bound method ProfileReport.to_notebook_iframe of >

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-01-06 14:13:51.296500&quot;&gt;&lt;title&gt;Customers Data Analysis&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# OBSERVATIONS
# From the profile above, the following data quality findings were observed:
# 1. There are no missing values found on the data.
# 2. There are no duplicate rows. No need for data cleaning.
